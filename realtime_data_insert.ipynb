# %%
from ibapi.contract import Contract
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
import psycopg2
import threading
from time import sleep
import pandas as pd
DB_HOST = 'localhost'
DB_NAME = 'us'
DB_USER = 'postgres'
DB_PASS = 'buddyrich134'
conn = psycopg2.connect(host=DB_HOST, dbname=DB_NAME, user=DB_USER, password=DB_PASS)
cursor = conn.cursor()
cursor.execute("SELECT distinct code from public.maincode where listed = 'us100';")
conn.commit()
code_list_1 = [i[0] for i in cursor.fetchall()]
code_list = code_list_1 + ['QQQ', "VOO"]
cursor.execute("SELECT distinct code from public.maincode where listed = 'us30';")
conn.commit()
code_list_2 = [i[0] for i in cursor.fetchall()]
code_list = code_list + code_list_2
code_list = list(set(code_list))
cursor.execute("SELECT distinct code from public.maincode where listed = 'us500';")
conn.commit()
code_list_3 = [i[0] for i in cursor.fetchall()]
code_l = [i for i in code_list_3 if i not in code_list]
code_list = code_list + code_l[0:200-len(code_list)]
len(code_list)
# Out:
# 200

# %%
class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        self.df = []
        self.minute = -1
        self.count = 0
        self.req_id_to_contract = {}

    def realtimeBar(self, reqId, time, open_, high, low, close, volume, wap, count):
        timestamp_utc = pd.to_datetime(time, unit='s', utc=True)
        tz = 'America/New_York'
        da = timestamp_utc.tz_convert(tz).strftime("%Y-%m-%d %H:%M:%S")
        # print(close, da, reqId)
        code = code_list[reqId-1]
        if da[-2:] == '00':
            self.df.append([da, code, open_, high, low, close, wap, volume])
            
def run_loop():
    app.run()

app = IBapi()
app.connect('127.0.0.1', 7496, 1232)
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()
reqID = 1
for symbol in code_list:
    # if symbol in ['IBM', 'CAT', 'CSCO']: continue
    contract = Contract()
    contract.symbol = symbol
    contract.secType = 'STK'
    contract.exchange = 'SMART'
    contract.currency = 'USD'
    app.reqRealTimeBars(reqId=reqID, contract=contract, barSize=5, whatToShow="TRADES", useRTH=0, realTimeBarsOptions=[])
    reqID += 1
# Out:
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usopt
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefnj
# ERROR 1 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 39.95 to 39
# ERROR 3 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.2 to 1
# ERROR 4 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 22.6 to 22
# ERROR 30 200 The contract description specified for CAT is ambiguous.
# ERROR 6 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 23.71 to 23
# ERROR 7 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.5 to 3
# ERROR 8 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 27.27 to 27
# ERROR 12 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 33.54 to 33
# ERROR 10 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.14 to 1
# ERROR 14 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 8.45 to 8
# ERROR 24 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 634.08 to 634
# ERROR 18 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 17.68 to 17
# ERROR 23 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.28 to 1
# ERROR 25 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.5 to 2
# ERROR 32 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 52.75 to 52
# ERROR 33 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 16.45 to 16
# ERROR 41 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 38.06 to 38
# ERROR 45 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 169.99 to 169
# ERROR 46 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.05 to 3
# ERROR 48 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 24.17 to 24
# ERROR 52 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 64.74 to 64
# ERROR 53 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 6.05 to 6
# ERROR 54 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.99 to 1
# ERROR 66 200 The contract description specified for IBM is ambiguous.
# ERROR 57 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.06 to 1
# ERROR 60 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 17.1 to 17
# ERROR 100 200 The contract description specified for CSCO is ambiguous.
# ERROR 68 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.75 to 4
# ERROR 71 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 11.62 to 11
# ERROR 73 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 19.18 to 19
# ERROR 74 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 15.06 to 15
# ERROR 75 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.15 to 5
# ERROR 81 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.17 to 7
# ERROR 80 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 23.94 to 23
# ERROR 84 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 22.34 to 22
# ERROR 90 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.23 to 4
# ERROR 88 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 245.5 to 245
# ERROR 94 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 10.25 to 10
# ERROR 101 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 21.52 to 21
# ERROR 103 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 24.5 to 24
# ERROR 104 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 17.26 to 17
# ERROR 109 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 15.4 to 15
# ERROR 117 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.01 to 7
# ERROR 120 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 129.81 to 129
# ERROR 121 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 10.89 to 10
# ERROR 124 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.03 to 3
# ERROR 130 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 12.09 to 12
# ERROR 136 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 50.02 to 50
# ERROR 135 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 22.91 to 22
# ERROR 143 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 34.62 to 34
# ERROR 155 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.15 to 3
# ERROR 157 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.78 to 3
# ERROR 159 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.57 to 1
# ERROR 160 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.98 to 5
# ERROR 163 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.95 to 5
# ERROR 172 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.21 to 5
# ERROR 177 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.01 to 7
# ERROR 108 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.43 to 1
# ERROR 197 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 17.91 to 17
# ERROR 188 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 38.05 to 38
# ERROR 180 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.16 to 2
# ERROR 128 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.31 to 4
# ERROR 26 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.01 to 1
# ERROR 106 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 28.21 to 28
# ERROR 51 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 10.52 to 10
# ERROR 20 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.14 to 5
# ERROR 85 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.11 to 2
# ERROR 113 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.27 to 7
# ERROR 62 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 10.76 to 10
# ERROR 11 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.01 to 5
# ERROR 183 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 38.5 to 38
# ERROR 174 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.04 to 3
# ERROR 38 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.18 to 7
# ERROR 194 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.8 to 2
# ERROR 112 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.2 to 1
# ERROR 63 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 25.99 to 25
# ERROR 35 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 27.79 to 27
# ERROR 158 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 8.09 to 8
# ERROR 31 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 16.31 to 16
# ERROR 192 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.11 to 1
# ERROR 36 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.13 to 4
# ERROR 185 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.93 to 3
# ERROR 195 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 36.82 to 36
# ERROR 131 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.15 to 1
# ERROR 61 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.18 to 2
# ERROR 9 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 12.25 to 12
# ERROR 199 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.41 to 4
# ERROR 122 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.45 to 5
# ERROR 55 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.09 to 7
# ERROR 198 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.38 to 4
# ERROR 179 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.24 to 1
# ERROR 76 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.02 to 3
# ERROR 86 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 9.33 to 9
# ERROR 187 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.13 to 1
# ERROR 133 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.17 to 3
# ERROR 40 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 11.98 to 11
# ERROR 37 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 70.36 to 70
# ERROR 144 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 8.14 to 8
# ERROR 28 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.56 to 3
# ERROR 99 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 76.59 to 76
# ERROR 15 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.96 to 4
# ERROR 69 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.55 to 7
# ERROR 13 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 13.96 to 13
# ERROR 114 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.15 to 1
# ERROR 34 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 52.72 to 52
# ERROR 72 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.82 to 7
# ERROR 164 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.99 to 1
# ERROR 162 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.13 to 5
# ERROR 134 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.29 to 3
# ERROR 173 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.68 to 1
# ERROR 50 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.5 to 5
# ERROR 138 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.05 to 3
# ERROR 190 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.09 to 1
# ERROR 182 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.04 to 5
# ERROR 123 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.39 to 1
# ERROR 87 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.6 to 1
# ERROR 29 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 12.84 to 12
# ERROR 97 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.01 to 3
# ERROR 153 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 31.53 to 31
# ERROR 116 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 6.84 to 6
# ERROR 167 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 88.65 to 88
# ERROR 150 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.1 to 1
# ERROR 93 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 25.3 to 25
# ERROR 92 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.25 to 1
# ERROR 47 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.16 to 4
# ERROR 17 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 23.48 to 23
# ERROR 141 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.47 to 1
# ERROR 67 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.9 to 7
# ERROR 82 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.77 to 4
# ERROR 176 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.91 to 2
# ERROR 196 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.06 to 2
# ERROR 137 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.01 to 2
# ERROR 126 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 35.26 to 35
# ERROR 27 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 88.52 to 88
# ERROR 152 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.58 to 1
# ERROR 147 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.46 to 3
# ERROR 49 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.29 to 1
# ERROR 171 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.3 to 1
# ERROR 149 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.73 to 3
# ERROR 165 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.81 to 4
# ERROR 83 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.67 to 4
# ERROR 91 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.87 to 3
# ERROR 39 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.03 to 1
# ERROR 56 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.68 to 4
# ERROR 2 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.8 to 4
# ERROR 78 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.76 to 1
# ERROR 166 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.12 to 4
# ERROR 95 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.05 to 2
# ERROR 125 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.47 to 1
# ERROR 170 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 6.26 to 6
# ERROR 127 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.76 to 5
# ERROR 142 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.37 to 2
# ERROR 96 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 39.06 to 39
# ERROR 77 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.23 to 3
# ERROR 21 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.67 to 1
# ERROR 16 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.86 to 7
# ERROR 168 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.04 to 3
# ERROR 148 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.25 to 1
# ERROR 65 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.2 to 1
# ERROR 119 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.53 to 1
# ERROR 191 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.05 to 1
# ERROR 58 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.02 to 1
# ERROR 193 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.13 to 4
# ERROR 107 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.51 to 1
# ERROR 189 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.13 to 1
# ERROR 110 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.37 to 1
# ERROR 140 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.04 to 2
# ERROR 186 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.73 to 5
# ERROR 102 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.14 to 3
# ERROR 118 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 4.5 to 4
# ERROR 184 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.15 to 2
# ERROR 146 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.24 to 7
# ERROR 19 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.61 to 2
# ERROR 98 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.25 to 1
# ERROR 79 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 15.55 to 15
# ERROR 115 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 14.73 to 14
# ERROR 200 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.49 to 1
# ERROR 151 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.37 to 2
# ERROR 5 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 5.02 to 5
# ERROR 105 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.84 to 3
# ERROR 70 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.08 to 1
# ERROR 132 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.25 to 1
# ERROR 178 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.01 to 1
# ERROR 154 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.21 to 3
# ERROR 161 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 3.05 to 3
# ERROR 145 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.64 to 1
# ERROR 156 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.48 to 7
# ERROR 89 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.99 to 2
# ERROR 59 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.11 to 2
# ERROR 43 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.27 to 2
# ERROR 42 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 11.94 to 11
# ERROR 181 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.45 to 2
# ERROR 64 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 8.15 to 8
# ERROR 175 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.08 to 2
# ERROR 139 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.09 to 2
# ERROR 44 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.07 to 1
# ERROR 169 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 2.9 to 2
# ERROR 111 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.08 to 1
# ERROR 22 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 7.83 to 7
# ERROR 129 2176 Warning: Your API version does not support fractional share size rules. Please upgrade to a minimum version 163. Trimmed value 1.23 to 1

# %%
import pandas as pd
import threading
import time
from IPython.display import clear_output
import psycopg2
class ContinuousProcessor:
    def __init__(self):
        self.index_da = None
        self.lock = threading.Lock()
        self.running = True
        self.reqId = 250
        
        self.conn = self.get_db_connection()
        self.cursor = self.conn.cursor()

        self.reqId += 1
    def get_db_connection(self):
        DB_HOST = 'localhost'
        DB_NAME = 'us'
        DB_USER = 'postgres'
        DB_PASS = 'buddyrich134'
        conn = psycopg2.connect(host=DB_HOST, dbname=DB_NAME, user=DB_USER, password=DB_PASS)
        return conn
    def backtest_code(self, pivoted, code, rolling=5, benchmark_index='QQQ'):
        return None
    def orderStatus(self, orderId, status: str, filled,
                         remaining, avgFillPrice: float, permId: int,
                         parentId: int, lastFillPrice: float, clientId: int,
                         whyHeld: str, mktCapPrice: float):
        super().orderStatus(orderId, status, filled, remaining,
                            avgFillPrice, permId, parentId, lastFillPrice, clientId, whyHeld, mktCapPrice)
        print(orderId, status, filled, remaining, avgFillPrice, permId, parentId, lastFillPrice, whyHeld)
    def continuous_loop(self):
        while self.running:
            clear_output(wait=True)
            if len(app.df) == 0: 
                # print("market not open, app.df has len 0")
                # print(pd.to_datetime(time.time()*1000000000))
                time.sleep(10)
                continue
            df = pd.DataFrame(app.df[-2000:], columns=['da', 'code', 'op', 'hi', 'lo', 'cl', 'wap', 'volume'])
            index = df['da'].max()
            if len(df) >= 200 and self.index_da != index:
                self.index_da = index
                time.sleep(3)
                df = pd.DataFrame(app.df[-2000:], columns=['da', 'code', 'op', 'hi', 'lo', 'cl', 'wap', 'volume']) 
                df = df.drop_duplicates(subset=['da', 'code'])
                insert_df = df[pd.to_datetime(df['da']) == index]
                self.cursor.executemany("INSERT INTO public.stock_price_5m (da, code, op, hi, lo, cl, wap, vol) VALUES (%s, %s, %s, %s, %s, %s, %s, %s);", insert_df.values.tolist())
                self.conn.commit()
            else:
                time.sleep(10)
                ####

    def stop(self):
        self.running = False

processor = ContinuousProcessor()
loop_thread = threading.Thread(target=processor.continuous_loop, daemon=True)
loop_thread.start()
